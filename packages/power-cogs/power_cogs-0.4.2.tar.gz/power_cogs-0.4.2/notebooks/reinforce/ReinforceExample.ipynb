# %%
from power_cogs.callbacks.callback import *
from power_cogs.callbacks.logger_callback import *
from power_cogs.callbacks.class_method_callback import ClassMethodCallback
from power_cogs.config.config import load_config
from power_cogs.examples.reinforce.reinforce_trainer import ReinforceTrainer
from typing import Dict, Any, Optional
from omegaconf import OmegaConf
from power_cogs.utils import *

# %%
rt = ReinforceTrainer.from_config_file("reinforce.yaml",
                                      overrides={"logging_config":{"checkpoint_interval":5}})
# Out:
# 2021-09-19 13:03:20.158 | INFO     | power_cogs.logging.tensorboard_logger:__init__:23 - Follow tensorboard logs with: tensorboard --logdir /home/shyam/Code/power_cogs/notebooks/reinforce/checkpoints/2021-09-19-13:03:19_ReinforceTrainer/tensorboard_logs/default

# %%
rt.train(epochs=1000)
# Out:
# average_summed_rewards:-174.00862846137923--max_summed_rewards:22.46800321810916--loss:-0.01025564262527041--max_loss:0.022354645654559135--sum_loss:-0.20511285250540823--epoch:3--net.0.0.weight_grad:0.0036803775001317263--net.0.0.bias_grad:-0.003866246435791254--net.1.0.weight_grad:-0.011016927659511566--net.1.0.bias_grad:-0.01111503504216671--net.2.0.weight_grad:-0.02294710837304592--net.2.0.bias_grad:-0.24146953225135803--net.3.weight_grad:1.3096723705530167e-08--net.3.bias_grad:-2.9802322387695312e-08:   0%|          | 3/1000 [00:02<14:34,  1.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4a777fa883fa> in <module>
# ----> 1 rt.train(epochs=1000)
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#     120             elif rule == "setup":
#     121                 wrapped = callback.wrap_setup(wrapped)
# --> 122         return wrapped(*args, **kwargs)
#     123
#     124     return _inner
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#      79             wrapped_class = self.get_wrapped_class(f, args)
#      80             self.before(wrapped_class, f, *args, **kwargs)
# ---> 81             return f(*args, **kwargs)
#      82
#      83         _inner.__signature__ = inspect.signature(f)
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#     120             elif rule == "setup":
#     121                 wrapped = callback.wrap_setup(wrapped)
# --> 122         return wrapped(*args, **kwargs)
#     123
#     124     return _inner
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#      89             wrapped_class = self.get_wrapped_class(f, args)
#      90             try:
# ---> 91                 out = f(*args, **kwargs)
#      92             except Exception as e:
#      93                 self.handle_exception(e)
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/base/torch/base_torch_trainer.py in train(self, batch_size, epochs, visualize)
#     135         for i in bar:
#     136             self.current_iteration += 1
# --> 137             output = self._train_iter(batch_size, self.current_iteration)
#     138             metrics = output.get("metrics", {})
#     139             description = "--".join(["{}:{}".format(k, metrics[k]) for k in metrics])
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#     120             elif rule == "setup":
#     121                 wrapped = callback.wrap_setup(wrapped)
# --> 122         return wrapped(*args, **kwargs)
#     123
#     124     return _inner
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#      59         @wraps(f)
#      60         def _inner(*args, **kwargs):
# ---> 61             return self._run(f, *args, **kwargs)
#      62
#      63         _inner.__signature__ = inspect.signature(f)
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _run(self, f, *args, **kwargs)
#      45         self.before(wrapped_class, f, *args, **kwargs)
#      46         try:
# ---> 47             out = f(*args, **kwargs)
#      48         except Exception as e:
#      49             ex = self.handle_exception(e)
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#     120             elif rule == "setup":
#     121                 wrapped = callback.wrap_setup(wrapped)
# --> 122         return wrapped(*args, **kwargs)
#     123
#     124     return _inner
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/callbacks/callback.py in _inner(*args, **kwargs)
#      89             wrapped_class = self.get_wrapped_class(f, args)
#      90             try:
# ---> 91                 out = f(*args, **kwargs)
#      92             except Exception as e:
#      93                 self.handle_exception(e)
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/base/torch/base_torch_trainer.py in _train_iter(self, batch_size, epoch)
#     115     @after([ClassMethodCallback("emit_metrics")])
#     116     def _train_iter(self, batch_size: int = 32, epoch: int = 0):
# --> 117         out = self.train_iter(batch_size, epoch)
#     118         out["epoch"] = epoch
#     119         return out
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/examples/reinforce/reinforce_trainer.py in train_iter(self, batch_size, epoch)
#      53     def train_iter(self, batch_size: int = 32, epoch: int = 0):
#      54         losses = []
# ---> 55         rollouts = self.dataset.get_rollouts(self.cluster, self.model)
#      56         total_rewards = []
#      57         for rollout in rollouts:
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/examples/reinforce/rollout_dataset.py in get_rollouts(self, cluster, model)
#      69             {"model": model, "render": False} for i in range(self.num_rollouts)
#      70         ]
# ---> 71         return cluster.execute_list(rollout_workers, rollout_args)
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/cluster/cluster.py in execute_list(self, executions, execution_args)
#      68                     break
#      69                 arg = execution_args[i]
# ---> 70                 out.append(self.execute(execution, **arg))
#      71                 i += 1
#      72         return out
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/cluster/local_cluster.py in execute(self, execution, *args, **kwargs)
#      18
#      19     def execute(self, execution, *args, **kwargs):
# ---> 20         return [execution.execute(*args, **kwargs)]
#      21
#      22     def put(self, obj, name):
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/cluster/execution/rollout_execution.py in execute(self, *args, **kwargs)
#     141
#     142     def execute(self, *args, **kwargs):
# --> 143         return self.rollout(*args, **kwargs)
#     144
#     145     @classmethod
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/cluster/execution/rollout_execution.py in rollout(self, model, render, random_policy, close)
#      99             observations.append(observation.cpu().detach().numpy())
#     100
# --> 101             observation, reward, done, info = self.env.step(action)
#     102             rewards.append(reward)
#     103             dones.append(float(done))
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/gym/envs/box2d/lunar_lander.py in step(self, action)
#     300                                            True)
#     301
# --> 302         self.world.Step(1.0/FPS, 6*30, 2*30)
#     303
#     304         pos = self.lander.position
#
# KeyboardInterrupt:

# %%
from power_cogs.wrappers.tune_wrapper import TuneWrapper

# %%
wrapper = TuneWrapper(rt)

# %%
wrapper.tune()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-abc03024d3b1> in <module>
# ----> 1 wrapper.tune()
#
# ~/anaconda3/envs/py38/lib/python3.8/site-packages/power_cogs-0.4.1-py3.8.egg/power_cogs/wrappers/tune_wrapper.py in tune(self)
#     194     def tune(self):
#     195         self.trainer.current_iteration = 0
# --> 196         tune_wrapper_config = self.config["tune_wrapper_config"]
#     197         mlflow_config = tune_wrapper_config["mlflow"]
#     198         wandb_config = tune_wrapper_config["wandb"]
#
# KeyError: 'tune_wrapper_config'
