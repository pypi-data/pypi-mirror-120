# %% [markdown]
# # Introduction

# %%
# %load_ext autoreload

# %autoreload 1

# %%
from worlds.levels import get_robo

# %%
bot = get_robo('test')
# Out:
# Maze()

# %%
bot.turn_left()
bot.turn_left()
bot.turn_left()

# %%
bot.check()

# %% [markdown]
# 1. wallcolr, bordercolor,
# 2. margin bottom,left
# 3. max - 85%, min- 450
# 4. image(area-6px )
# 5. gh= max(0.85 * sh, 420)
# h = gh+30
